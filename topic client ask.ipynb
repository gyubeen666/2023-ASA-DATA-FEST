# %%
import numpy as np
import pandas as pd

# %%
questionpost_df = pd.read_csv('labeled data.csv')
questionpost_df
# Out:
#                                  QuestionUno  \
# 0       B7C95D50-6C81-4E61-BC16-81077B7D3F7E
# 1       C579CE49-6B7A-44E7-A203-5D3E52623804
# 2       F3A78AD3-D3D4-447F-BEAF-F62F1D1D4CCE
# 3       5F8506D3-D9F1-48EE-8081-D30259DBF4E8
# 4       B4C814C9-8983-413F-8BC4-F2BE01665555
# ...                                      ...
# 405016  72E29316-3E1B-4925-B66C-FF68AD92A9CA
# 405017  6F1389B8-6BEC-448D-AA2F-81210CAF15AE
# 405018  6F1389B8-6BEC-448D-AA2F-81210CAF15AE
# 405019  C6C77CE7-5603-48B6-B41C-9F2DD0291563
# 405020  C6C77CE7-5603-48B6-B41C-9F2DD0291563
#
#                                                  PostText  label
# 0       Do you still need help with this issue?  It ha...      0
# 1                                                 Anyone?      1
# 2       Yes those are the right forms.  Im sorry I did...      0
# 3       Hi You do make some good points.  The differen...      0
# 4       My father passed away and I have DNA test resu...      1
# ...                                                   ...    ...
# 405016       Thank you so much!! I appreciate your reply.      1
# 405017  HiMy exwife  divorced me in 21.  We share join...      1
# 405018  Hi It seems like you basically have two questi...      0
# 405019  Im in the beginning stages of getting a divorc...      1
# 405020  RkkiI would recommend you visit httpswww.wyomi...      1
#
# [405021 rows x 3 columns]

# %%
questionpost_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405021 entries, 0 to 405020
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   QuestionUno  405021 non-null  object
#  1   PostText     405021 non-null  object
#  2   label        405021 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 9.3+ MB

# %%
question_df = pd.read_csv("questions.csv")
question_df.head()
# Out:
#    Id StateAbbr                           QuestionUno  \
# 0   1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1   2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2   3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3   4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4   5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
#
#                             CategoryUno                      Category  \
# 0  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 1  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 2  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 3  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 4  F6016FBD-9501-4448-BCD3-BBB0E834E33B  Consumer Financial Questions
#
#                          SubcategoryUno  \
# 0  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 1  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 2  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 3  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 4  73FE486E-2B51-456A-A6D9-78A7D05802AA
#
#                                        Subcategory  \
# 0  Family/Divorce/Custody/Visitation/Child Support
# 1                      Civil/Constitutional Rights
# 2                      Civil/Constitutional Rights
# 3  Family/Divorce/Custody/Visitation/Child Support
# 4                    Bankruptcy, Debts & Purchases
#
#                        AskedByClientUno           AskedOnUtc  \
# 0  9C35423C-914A-42BC-8EBC-A370E76E2178  2019-06-19 22:10:06
# 1  DF636AEE-7D08-4F90-9A5C-0A2A726C6B59  2019-06-19 23:34:36
# 2  DF636AEE-7D08-4F90-9A5C-0A2A726C6B59  2019-06-19 23:57:18
# 3  C9C3FA40-0D60-49B9-97F1-63AFEFAFA484  2019-06-20 02:33:14
# 4  ED7DEA10-CDB7-4A05-891D-889D1EA710BE  2019-06-20 17:04:47
#
#                      TakenByAttorneyUno           TakenOnUtc  \
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2  FA34142B-1575-4720-981C-2D28C3560137  2019-06-22 02:37:16
# 3  FA34142B-1575-4720-981C-2D28C3560137  2019-07-27 18:04:08
# 4                                   NaN                  NaN
#
#                     ClosedByAttorneyUno          ClosedOnUtc  \
# 0                                   NaN  2019-08-13 15:09:06
# 1                                   NaN  2019-08-13 15:09:14
# 2  FA34142B-1575-4720-981C-2D28C3560137  2019-06-24 19:02:35
# 3  FA34142B-1575-4720-981C-2D28C3560137  2019-07-31 05:49:18
# 4                                   NaN  2019-08-13 15:09:20
#
#          LegalDeadline
# 0  2019-07-08 00:00:00
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
question_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202879 entries, 0 to 202878
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id                   202879 non-null  int64
#  1   StateAbbr            202879 non-null  object
#  2   QuestionUno          202879 non-null  object
#  3   CategoryUno          202879 non-null  object
#  4   Category             202879 non-null  object
#  5   SubcategoryUno       202879 non-null  object
#  6   Subcategory          202879 non-null  object
#  7   AskedByClientUno     202841 non-null  object
#  8   AskedOnUtc           202879 non-null  object
#  9   TakenByAttorneyUno   144005 non-null  object
#  10  TakenOnUtc           145651 non-null  object
#  11  ClosedByAttorneyUno  137787 non-null  object
#  12  ClosedOnUtc          199085 non-null  object
#  13  LegalDeadline        43944 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 21.7+ MB

# %%
df = pd.merge(questionpost_df, question_df, on='QuestionUno', how='left')
df.head()
# Out:
#                             QuestionUno  \
# 0  B7C95D50-6C81-4E61-BC16-81077B7D3F7E
# 1  C579CE49-6B7A-44E7-A203-5D3E52623804
# 2  F3A78AD3-D3D4-447F-BEAF-F62F1D1D4CCE
# 3  5F8506D3-D9F1-48EE-8081-D30259DBF4E8
# 4  B4C814C9-8983-413F-8BC4-F2BE01665555
#
#                                             PostText  label      Id StateAbbr  \
# 0  Do you still need help with this issue?  It ha...      0  118516        AK
# 1                                            Anyone?      1  118517        AK
# 2  Yes those are the right forms.  Im sorry I did...      0  118518        AK
# 3  Hi You do make some good points.  The differen...      0  118519        AK
# 4  My father passed away and I have DNA test resu...      1  118520        AK
#
#                             CategoryUno                  Category  \
# 0  2D43B4FD-FAC8-47C3-A891-085F5D74D64B  Housing and Homelessness
# 1  2D43B4FD-FAC8-47C3-A891-085F5D74D64B  Housing and Homelessness
# 2  A96DEADE-C287-4B31-BFF5-6C02E0640001       Family and Children
# 3  E31B199A-B01E-47E6-86DB-8D99B2BB7420                     Other
# 4  A96DEADE-C287-4B31-BFF5-6C02E0640001       Family and Children
#
#                          SubcategoryUno                Subcategory  \
# 0  6F28DF84-2BDA-48AE-97F8-A083D20E3EC8  Housing or Property Owned
# 1  6F28DF84-2BDA-48AE-97F8-A083D20E3EC8  Housing or Property Owned
# 2  372E3CF8-3543-4C71-BA48-DA3F52FC5792     Family/Divorce/Custody
# 3  3DBF3B9F-9ED0-4028-A4FE-0823B0012634                      Other
# 4  BB9683D7-FAE6-4E33-AF74-52E71373C8D7          Wills/Inheritance
#
#                        AskedByClientUno           AskedOnUtc  \
# 0  56A7173F-C8B2-4E17-8189-DBDB8EDDAA1C  2018-04-04 23:15:49
# 1  6CB2B648-61A3-425F-9B84-A7C637B83126  2018-04-05 17:46:54
# 2  00BB08E8-38C6-42CE-8A01-6C8A1F7F88E7  2018-04-05 23:02:22
# 3  6CB2B648-61A3-425F-9B84-A7C637B83126  2018-04-07 22:49:08
# 4  2761B481-9CAD-4494-B8CB-27AF221FDA69  2018-04-12 10:52:38
#
#                      TakenByAttorneyUno           TakenOnUtc  \
# 0  0293D737-A73B-47D8-8D26-FE5AB33F67E1  2018-04-25 18:08:21
# 1                                   NaN                  NaN
# 2  C4EA5672-72E4-47CD-A4C2-E4A7C874E40A  2018-04-05 23:11:26
# 3  C4EA5672-72E4-47CD-A4C2-E4A7C874E40A  2018-04-09 18:34:20
# 4                                   NaN                  NaN
#
#                     ClosedByAttorneyUno          ClosedOnUtc  \
# 0  0293D737-A73B-47D8-8D26-FE5AB33F67E1  2018-05-05 18:09:47
# 1                                   NaN  2018-05-07 17:12:17
# 2  C4EA5672-72E4-47CD-A4C2-E4A7C874E40A  2018-04-18 17:53:16
# 3  C4EA5672-72E4-47CD-A4C2-E4A7C874E40A  2018-04-28 22:15:35
# 4                                   NaN  2018-05-22 22:31:34
#
#          LegalDeadline
# 0                  NaN
# 1                  NaN
# 2  2018-04-18 00:00:00
# 3                  NaN
# 4                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405021 entries, 0 to 405020
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   QuestionUno          405021 non-null  object
#  1   PostText             405021 non-null  object
#  2   label                405021 non-null  int64
#  3   Id                   405021 non-null  int64
#  4   StateAbbr            405021 non-null  object
#  5   CategoryUno          405021 non-null  object
#  6   Category             405021 non-null  object
#  7   SubcategoryUno       405021 non-null  object
#  8   Subcategory          405021 non-null  object
#  9   AskedByClientUno     405001 non-null  object
#  10  AskedOnUtc           405021 non-null  object
#  11  TakenByAttorneyUno   357758 non-null  object
#  12  TakenOnUtc           359184 non-null  object
#  13  ClosedByAttorneyUno  330401 non-null  object
#  14  ClosedOnUtc          402296 non-null  object
#  15  LegalDeadline        94566 non-null   object
# dtypes: int64(2), object(14)
# memory usage: 52.5+ MB

# %%
df["PostText"][100]
# Out:
# 'You should wait until the judge rules on your Expedited Motion. If the judge rules against you you have to follow the judges ruling. If you pick them up before the judge rules that could really make it look like you will do whatever you want regardless of what the court says.  That could seriously hamper your custody case in the future.'

# %% [markdown]
# ## 1. Clients

# %%
import matplotlib.pyplot as plt
import nltk
import textwrap

from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/home/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops = stops.union({
    'said', 'would', 'could', 'told', 'also', 'one', 'two',
    'mr', 'new', 'year', 
})

# %%
df1 = df[df["label"] == 1] 
df1 = df1[["PostText", "Category" ]]
df1 = df1.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 298135 entries, 1 to 405020
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   PostText  298135 non-null  object
#  1   Category  298135 non-null  object
# dtypes: object(2)
# memory usage: 6.8+ MB

# %%
vectorizer = CountVectorizer(stop_words=stops)
X = vectorizer.fit_transform(df1['PostText'])

# %%
lda = LatentDirichletAllocation(
    n_components=10, # default: 10
    random_state=12345,
)
lda.fit(X)
# Out:
# LatentDirichletAllocation(random_state=12345)

# %%
def plot_top_words(model, feature_names, n_top_words=10):
  fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
  axes = axes.flatten()
  for topic_idx, topic in enumerate(model.components_):
    top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
    top_features = [feature_names[i] for i in top_features_ind]
    weights = topic[top_features_ind]

    ax = axes[topic_idx]
    ax.barh(top_features, weights, height=0.7)
    ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
    ax.invert_yaxis()
    ax.tick_params(axis="both", which="major", labelsize=20)
    for i in "top right left".split():
        ax.spines[i].set_visible(False)
    fig.suptitle('LDA', fontsize=40)

  plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
  plt.show()

# %%
feature_names = vectorizer.get_feature_names_out()
plot_top_words(lda, feature_names);
