# %%
import numpy as np
import pandas as pd

# %%
questionpost_df = pd.read_csv('questionposts.csv')
questionpost_df
# Out:
#             Id StateAbbr                           QuestionUno  \
# 0            1        AK  B7C95D50-6C81-4E61-BC16-81077B7D3F7E
# 1            2        AK  C579CE49-6B7A-44E7-A203-5D3E52623804
# 2            3        AK  F3A78AD3-D3D4-447F-BEAF-F62F1D1D4CCE
# 3            4        AK  5F8506D3-D9F1-48EE-8081-D30259DBF4E8
# 4            5        AK  B4C814C9-8983-413F-8BC4-F2BE01665555
# ...        ...       ...                                   ...
# 405462  405463        WY  72E29316-3E1B-4925-B66C-FF68AD92A9CA
# 405463  405464        WY  6F1389B8-6BEC-448D-AA2F-81210CAF15AE
# 405464  405465        WY  6F1389B8-6BEC-448D-AA2F-81210CAF15AE
# 405465  405466        WY  C6C77CE7-5603-48B6-B41C-9F2DD0291563
# 405466  405467        WY  C6C77CE7-5603-48B6-B41C-9F2DD0291563
#
#                   CreatedUtc  \
# 0       2018-04-25T18:09:30Z
# 1       2018-04-17T21:15:28Z
# 2       2018-04-18T17:51:41Z
# 3       2018-04-18T22:15:44Z
# 4       2018-04-12T10:52:50Z
# ...

# %%
questionpost_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405467 entries, 0 to 405466
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Id           405467 non-null  int64
#  1   StateAbbr    405467 non-null  object
#  2   QuestionUno  405437 non-null  object
#  3   CreatedUtc   405452 non-null  object
#  4   PostText     405051 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 15.5+ MB

# %%
question_df = pd.read_csv("questions.csv")
question_df.head()
# Out:
#    Id StateAbbr                           QuestionUno  \
# 0   1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1   2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2   3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3   4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4   5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
#
#                             CategoryUno                      Category  \
# 0  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 1  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 2  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 3  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 4  F6016FBD-9501-4448-BCD3-BBB0E834E33B  Consumer Financial Questions
#
#                          SubcategoryUno  \
# 0  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 1  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 2  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 3  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# ...

# %%
question_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202879 entries, 0 to 202878
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id                   202879 non-null  int64
#  1   StateAbbr            202879 non-null  object
#  2   QuestionUno          202879 non-null  object
#  3   CategoryUno          202879 non-null  object
#  4   Category             202879 non-null  object
#  5   SubcategoryUno       202879 non-null  object
#  6   Subcategory          202879 non-null  object
#  7   AskedByClientUno     202841 non-null  object
#  8   AskedOnUtc           202879 non-null  object
#  9   TakenByAttorneyUno   144005 non-null  object
#  10  TakenOnUtc           145651 non-null  object
#  11  ClosedByAttorneyUno  137787 non-null  object
#  12  ClosedOnUtc          199085 non-null  object
#  13  LegalDeadline        43944 non-null   object
# dtypes: int64(1), object(13)
# ...

# %%
df = pd.merge(questionpost_df, question_df, on='QuestionUno', how='left')
df.head()
# Out:
#    Id_x StateAbbr_x                           QuestionUno  \
# 0     1          AK  B7C95D50-6C81-4E61-BC16-81077B7D3F7E
# 1     2          AK  C579CE49-6B7A-44E7-A203-5D3E52623804
# 2     3          AK  F3A78AD3-D3D4-447F-BEAF-F62F1D1D4CCE
# 3     4          AK  5F8506D3-D9F1-48EE-8081-D30259DBF4E8
# 4     5          AK  B4C814C9-8983-413F-8BC4-F2BE01665555
#
#              CreatedUtc                                           PostText  \
# 0  2018-04-25T18:09:30Z  Do you still need help with this issue?  It ha...
# 1  2018-04-17T21:15:28Z                                            Anyone?
# 2  2018-04-18T17:51:41Z  Yes those are the right forms.  Im sorry I did...
# 3  2018-04-18T22:15:44Z  Hi You do make some good points.  The differen...
# 4  2018-04-12T10:52:50Z  My father passed away and I have DNA test resu...
#
#        Id_y StateAbbr_y                           CategoryUno  \
# 0  118516.0          AK  2D43B4FD-FAC8-47C3-A891-085F5D74D64B
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405467 entries, 0 to 405466
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id_x                 405467 non-null  int64
#  1   StateAbbr_x          405467 non-null  object
#  2   QuestionUno          405437 non-null  object
#  3   CreatedUtc           405452 non-null  object
#  4   PostText             405051 non-null  object
#  5   Id_y                 405437 non-null  float64
#  6   StateAbbr_y          405437 non-null  object
#  7   CategoryUno          405437 non-null  object
#  8   Category             405437 non-null  object
#  9   SubcategoryUno       405437 non-null  object
#  10  Subcategory          405437 non-null  object
#  11  AskedByClientUno     405417 non-null  object
#  12  AskedOnUtc           405437 non-null  object
#  13  TakenByAttorneyUno   358145 non-null  object
#  14  TakenOnUtc           359573 non-null  object
# ...

# %%
df["PostText"][100]
# Out:
# 'You should wait until the judge rules on your Expedited Motion. If the judge rules against you you have to follow the judges ruling. If you pick them up before the judge rules that could really make it look like you will do whatever you want regardless of what the court says.  That could seriously hamper your custody case in the future.'

# %%
import matplotlib.pyplot as plt
import nltk
import textwrap

from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nltk.download('stopwords')
stops = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/home/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops = stops.union({
    'said', 'would', 'could', 'told', 'also', 'one', 'two',
    'mr', 'new', 'year', 
})

# %%
df1 = df[["Id_x","StateAbbr_x" , "QuestionUno","PostText", "Category" ]]
df1 = df1.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405021 entries, 0 to 405466
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Id_x         405021 non-null  int64
#  1   StateAbbr_x  405021 non-null  object
#  2   QuestionUno  405021 non-null  object
#  3   PostText     405021 non-null  object
#  4   Category     405021 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 18.5+ MB

# %%
vectorizer = CountVectorizer(stop_words=stops)
X = vectorizer.fit_transform(df1['PostText'])

# %%
lda = LatentDirichletAllocation(
    n_components=10, # default: 10
    random_state=12345,
)
lda.fit(X)
# Out:
# LatentDirichletAllocation(random_state=12345)

# %%
def plot_top_words(model, feature_names, n_top_words=10):
  fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
  axes = axes.flatten()
  for topic_idx, topic in enumerate(model.components_):
    top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
    top_features = [feature_names[i] for i in top_features_ind]
    weights = topic[top_features_ind]

    ax = axes[topic_idx]
    ax.barh(top_features, weights, height=0.7)
    ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
    ax.invert_yaxis()
    ax.tick_params(axis="both", which="major", labelsize=20)
    for i in "top right left".split():
        ax.spines[i].set_visible(False)
    fig.suptitle('LDA', fontsize=40)

  plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
  plt.show()

# %%
feature_names = vectorizer.get_feature_names_out()
plot_top_words(lda, feature_names);
